# %% [markdown]
# Imports

# %%
import sys
sys.path.append('../src')

from load_data import *
from eda_num import *
from eda_text import *
from preprocess_num import *
from preprocess_text import *
from vectorize_text import *

# %% [markdown]
# Chargement des données numériques

# %%
num_data = load_all_numerical_data()

# %% [markdown]
# EDA numérique

# %%
stats_num = comprehensive_eda_numerical(num_data)

# %% [markdown]
# Prétraitement données numériques

# %%
processed_num = preprocess_numerical_data(num_data, remove_outliers_flag=False)

# %% [markdown]
# Chargement des données textuelles

# %%
df_train, df_test = load_all_text_data()

# %% [markdown]
# EDA textuelle

# %%
stats_text = comprehensive_eda_text(df_train, df_test)

# %% [markdown]
# Prétraitement texte

# %%
df_train_clean, df_test_clean = preprocess_text_data(df_train, df_test)

# %% [markdown]
# Vectorisation

# %%
vectorize_all_text_data(df_train_clean, df_test_clean)
